# %% [markdown]
# Detectando e fazendo segmentação de imagens YOLOv8

# %%
# Instalando e configurando o YOLOv8 (ultralytics é a empresa que desenvolveu)
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 9.4 MB/s eta 0:00:00
# ...

# %%
# Importando o pacote
import ultralytics

# %%
# Importando as bilbiotecas
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
# Chamando a biblioteca YOLOv8 usando yolom com confiança de 0.5 via lnha de comando, o download é feito automaticamente
# !yolo task=segment mode=predict model=yolov8m-seg.pt conf=0.5 source='/content/avião.jpg' save=True
# Out:
# ...
# 100% 52.4M/52.4M [00:05<00:00, 10.7MB/s]
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27268704 parameters, 0 gradients
#
# image 1/1 /content/avião.jpg: 384x640 4 airplanes, 141.6ms
# Speed: 2.8ms preprocess, 141.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/predict

# %%
# Criando função para mostrar a imagem
def mostrar(img):
  fig = plt.gcf() # gcf limpa os eixos
  fig.set_size_inches(16,10) # 16/10 tamanho da imagem em polegadas
  plt.axis('off') # off para não mostrar os valores nos eixos x e y
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # Convertendo para o formato padrão RGB
  plt.show()

# %%
seg = cv2.imread('/content/runs/segment/predict/avião.jpg')
mostrar(seg)

# %%
# Testando outra imagem
# !yolo task=segment mode=predict model=yolov8m-seg.pt conf=0.5 source='/content/diversos1.jpg' save=True
# Out:
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27268704 parameters, 0 gradients
#
# image 1/1 /content/diversos1.jpg: 480x640 1 person, 1 airplane, 1 suitcase, 320.8ms
# Speed: 6.0ms preprocess, 320.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/predict2

# %%
seg = cv2.imread('/content/runs/segment/predict2/diversos1.jpg')
mostrar(seg)

# %%
# Testando outra imagem novamente com yolov8x
# !yolo task=segment mode=predict model=yolov8x-seg.pt conf=0.5 source='/content/bagagem.jpg' save=True
# Out:
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71797696 parameters, 0 gradients
#
# image 1/1 /content/bagagem.jpg: 640x576 3 persons, 2 suitcases, 113.8ms
# Speed: 8.9ms preprocess, 113.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/segment/predict9

# %%
seg = cv2.imread('/content/runs/segment/predict9/bagagem.jpg')
mostrar(seg)
